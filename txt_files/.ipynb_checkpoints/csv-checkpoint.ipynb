# %%
import pandas as pd
from bs4 import BeautifulSoup
import os

# %%
def read_html_from_file(path):
    with open(path, 'r', encoding='utf-8', errors='replace') as file:
            content = file.read()
            return content

# %%
def parse_job_details(soup):
    jobs = soup.find_all('div', class_='job_seen_beacon')
    job_titles, companies, locations, salaries, job_types, descriptions, dates, links = [], [], [], [], [], [], [], []

    # Loop through each job listing
    for job in jobs:
        # Get job titles
        title_elements = job.find_all('h2', class_=['jobTitle css-198pbd eu4oa1w0', 'jobTitle jobTitle-newJob css-198pbd eu4oa1w0'])
        for h2 in title_elements:
            job_name_span = h2.find('span', id=lambda x: x and x.startswith('jobTitle-'))
            if job_name_span:
                job_name = job_name_span.get('title', job_name_span.text)
                job_titles.append(job_name)

        # Get company and location details
        company_div = job.find('span', {'data-testid': 'company-name'})
        location_div = job.find('div', {'data-testid': 'text-location'})
        if company_div:
            companies.append(company_div.text)
        if location_div:
            locations.append(location_div.text)

        # Get salary and job type details
        pay_div = job.find('div', class_='salary-snippet-container')
        type_div = job.find('div', class_='metadata css-5zy3wz eu4oa1w0')
        salaries.append(pay_div.text.strip() if pay_div else 'Not Provided')
        job_types.append(type_div.find('div', {'data-testid': 'attribute_snippet_testid'}).text.strip() if type_div else 'Not Provided')

        # Get job description
        descr = job.find('div', class_='css-1u8dvic eu4oa1w0')
        if descr:
            descriptions.append(descr.find('ul').text.strip() if descr.find('ul') else '')
        
        # Get job posting date
        date_element = job.find('span', class_='css-qvloho eu4oa1w0')
        if date_element:
            dates.append(date_element.text.strip())

        # Get job link
        a_tag = job.find('h2', class_='jobTitle').find('a') if job.find('h2', class_='jobTitle') else None
        if a_tag:
            links.append("https://www.indeed.com" + a_tag.get('href', ''))

    return job_titles, companies, locations, salaries, job_types, descriptions, dates, links

# %%
def save_to_csv(dataframe, file_number):
    output_text = f"Cleaned_csvs/AI-UnitedStates-Page({file_number}).csv"
    dataframe.to_csv(output_text, index=False)

# %%
def process_files_in_folder(folder_path):
    # Get a list of all .txt files in the folder
    file_list = [f for f in os.listdir(folder_path) if f.endswith('.txt')]
    
    for file_name in file_list:
        if file_name.endswith(".txt"):
            file_path = os.path.join(folder_path, file_name)
            content = read_html_from_file(file_path)
            soup = BeautifulSoup(content, 'html.parser')
            job_titles, companies, locations, salaries, job_types, descriptions, dates, links = parse_job_details(soup)
            file_number = file_name.split('_')[1].split('.')[0]
            df = pd.DataFrame({
            'Job Title': job_titles,
            'Company': companies,
            'Location': locations,
            'Salary($)': salaries,
            'Job-Type': job_types,
            'Job-Description': descriptions,
            'Raw_Link': links})
            csv_file_name = f'Cleaned_csvs/page_{file_number}.csv'
            df.to_csv(csv_file_name, index=False)
            print(f'Saved {csv_file_name}')

# %%
folder_path = '.'
process_files_in_folder(folder_path)
# Out:
# Saved Cleaned_csvs/page_1.csv
# Saved Cleaned_csvs/page_10.csv
# Saved Cleaned_csvs/page_100.csv
# Saved Cleaned_csvs/page_1000.csv
# Saved Cleaned_csvs/page_1001.csv
# Saved Cleaned_csvs/page_101.csv
# Saved Cleaned_csvs/page_102.csv
# Saved Cleaned_csvs/page_103.csv
# Saved Cleaned_csvs/page_104.csv
# Saved Cleaned_csvs/page_105.csv
# Saved Cleaned_csvs/page_106.csv
# Saved Cleaned_csvs/page_107.csv
# Saved Cleaned_csvs/page_108.csv
# Saved Cleaned_csvs/page_109.csv
# Saved Cleaned_csvs/page_11.csv
# Saved Cleaned_csvs/page_110.csv
# Saved Cleaned_csvs/page_111.csv
# Saved Cleaned_csvs/page_112.csv
# Saved Cleaned_csvs/page_113.csv
# Saved Cleaned_csvs/page_114.csv
# Saved Cleaned_csvs/page_115.csv
# Saved Cleaned_csvs/page_116.csv
# Saved Cleaned_csvs/page_117.csv
# Saved Cleaned_csvs/page_118.csv
# Saved Cleaned_csvs/page_119.csv
# Saved Cleaned_csvs/page_12.csv
# Saved Cleaned_csvs/page_120.csv
# Saved Cleaned_csvs/page_121.csv
# Saved Cleaned_csvs/page_122.csv
# Saved Cleaned_csvs/page_123.csv
# Saved Cleaned_csvs/page_124.csv
# Saved Cleaned_csvs/page_125.csv
# Saved Cleaned_csvs/page_126.csv
# Saved Cleaned_csvs/page_127.csv
# Saved Cleaned_csvs/page_128.csv
# Saved Cleaned_csvs/page_129.csv
# Saved Cleaned_csvs/page_13.csv
# Saved Cleaned_csvs/page_130.csv
# Saved Cleaned_csvs/page_131.csv
# Saved Cleaned_csvs/page_132.csv
# Saved Cleaned_csvs/page_133.csv
# Saved Cleaned_csvs/page_134.csv
# Saved Cleaned_csvs/page_135.csv
# Saved Cleaned_csvs/page_136.csv
# Saved Cleaned_csvs/page_137.csv
# Saved Cleaned_csvs/page_138.csv
# Saved Cleaned_csvs/page_139.csv
# Saved Cleaned_csvs/page_14.csv
# Saved Cleaned_csvs/page_140.csv
# Saved Cleaned_csvs/page_141.csv
# Saved Cleaned_csvs/page_142.csv
# Saved Cleaned_csvs/page_143.csv
# Saved Cleaned_csvs/page_144.csv
# Saved Cleaned_csvs/page_145.csv
# Saved Cleaned_csvs/page_146.csv
# Saved Cleaned_csvs/page_147.csv
# Saved Cleaned_csvs/page_148.csv
# Saved Cleaned_csvs/page_149.csv
# Saved Cleaned_csvs/page_15.csv
# Saved Cleaned_csvs/page_150.csv
# Saved Cleaned_csvs/page_151.csv
# Saved Cleaned_csvs/page_152.csv
# Saved Cleaned_csvs/page_153.csv
# Saved Cleaned_csvs/page_154.csv
# Saved Cleaned_csvs/page_155.csv
# Saved Cleaned_csvs/page_156.csv
# Saved Cleaned_csvs/page_157.csv
# Saved Cleaned_csvs/page_158.csv
# Saved Cleaned_csvs/page_159.csv
# Saved Cleaned_csvs/page_16.csv
# Saved Cleaned_csvs/page_160.csv
# Saved Cleaned_csvs/page_161.csv
# Saved Cleaned_csvs/page_162.csv
# Saved Cleaned_csvs/page_163.csv
# Saved Cleaned_csvs/page_164.csv
# Saved Cleaned_csvs/page_165.csv
# Saved Cleaned_csvs/page_166.csv
# Saved Cleaned_csvs/page_167.csv
# Saved Cleaned_csvs/page_168.csv
# Saved Cleaned_csvs/page_169.csv
# Saved Cleaned_csvs/page_17.csv
# Saved Cleaned_csvs/page_170.csv
# Saved Cleaned_csvs/page_171.csv
# Saved Cleaned_csvs/page_172.csv
# Saved Cleaned_csvs/page_173.csv
# Saved Cleaned_csvs/page_174.csv
# Saved Cleaned_csvs/page_175.csv
# Saved Cleaned_csvs/page_176.csv
# Saved Cleaned_csvs/page_177.csv
# Saved Cleaned_csvs/page_178.csv
# Saved Cleaned_csvs/page_179.csv
# Saved Cleaned_csvs/page_18.csv
# Saved Cleaned_csvs/page_180.csv
# Saved Cleaned_csvs/page_181.csv
# Saved Cleaned_csvs/page_182.csv
# Saved Cleaned_csvs/page_183.csv
# Saved Cleaned_csvs/page_184.csv
# Saved Cleaned_csvs/page_185.csv
# Saved Cleaned_csvs/page_186.csv
# Saved Cleaned_csvs/page_187.csv
# Saved Cleaned_csvs/page_188.csv
# Saved Cleaned_csvs/page_189.csv
# Saved Cleaned_csvs/page_19.csv
# Saved Cleaned_csvs/page_190.csv
# Saved Cleaned_csvs/page_191.csv
# Saved Cleaned_csvs/page_192.csv
# Saved Cleaned_csvs/page_193.csv
# Saved Cleaned_csvs/page_194.csv
# Saved Cleaned_csvs/page_195.csv
# Saved Cleaned_csvs/page_196.csv
# Saved Cleaned_csvs/page_197.csv
# Saved Cleaned_csvs/page_198.csv
# Saved Cleaned_csvs/page_199.csv
# Saved Cleaned_csvs/page_2.csv
# Saved Cleaned_csvs/page_20.csv
# Saved Cleaned_csvs/page_200.csv
# Saved Cleaned_csvs/page_201.csv
# Saved Cleaned_csvs/page_202.csv
# Saved Cleaned_csvs/page_203.csv
# Saved Cleaned_csvs/page_204.csv
# Saved Cleaned_csvs/page_205.csv
# Saved Cleaned_csvs/page_206.csv
# Saved Cleaned_csvs/page_207.csv
# Saved Cleaned_csvs/page_208.csv
# Saved Cleaned_csvs/page_209.csv
# Saved Cleaned_csvs/page_21.csv
# Saved Cleaned_csvs/page_210.csv
# Saved Cleaned_csvs/page_211.csv
# Saved Cleaned_csvs/page_212.csv
# Saved Cleaned_csvs/page_213.csv
# Saved Cleaned_csvs/page_214.csv
# Saved Cleaned_csvs/page_215.csv
# Saved Cleaned_csvs/page_216.csv
# Saved Cleaned_csvs/page_217.csv
# Saved Cleaned_csvs/page_218.csv
# Saved Cleaned_csvs/page_219.csv
# Saved Cleaned_csvs/page_22.csv
# Saved Cleaned_csvs/page_220.csv
# Saved Cleaned_csvs/page_221.csv
# Saved Cleaned_csvs/page_222.csv
# Saved Cleaned_csvs/page_223.csv
# Saved Cleaned_csvs/page_224.csv
# Saved Cleaned_csvs/page_225.csv
# Saved Cleaned_csvs/page_226.csv
# Saved Cleaned_csvs/page_227.csv
# Saved Cleaned_csvs/page_228.csv
# Saved Cleaned_csvs/page_229.csv
# Saved Cleaned_csvs/page_23.csv
# Saved Cleaned_csvs/page_230.csv
# Saved Cleaned_csvs/page_231.csv
# Saved Cleaned_csvs/page_232.csv
# Saved Cleaned_csvs/page_233.csv
# Saved Cleaned_csvs/page_234.csv
# Saved Cleaned_csvs/page_235.csv
# Saved Cleaned_csvs/page_236.csv
# Saved Cleaned_csvs/page_237.csv
# Saved Cleaned_csvs/page_238.csv
# Saved Cleaned_csvs/page_239.csv
# Saved Cleaned_csvs/page_24.csv
# Saved Cleaned_csvs/page_240.csv
# Saved Cleaned_csvs/page_241.csv
# Saved Cleaned_csvs/page_242.csv
# Saved Cleaned_csvs/page_243.csv
# Saved Cleaned_csvs/page_244.csv
# Saved Cleaned_csvs/page_245.csv
# Saved Cleaned_csvs/page_246.csv
# Saved Cleaned_csvs/page_247.csv
# Saved Cleaned_csvs/page_248.csv
# Saved Cleaned_csvs/page_249.csv
# Saved Cleaned_csvs/page_25.csv
# Saved Cleaned_csvs/page_250.csv
# Saved Cleaned_csvs/page_251.csv
# Saved Cleaned_csvs/page_252.csv
# Saved Cleaned_csvs/page_253.csv
# Saved Cleaned_csvs/page_254.csv
# Saved Cleaned_csvs/page_255.csv
# Saved Cleaned_csvs/page_256.csv
# Saved Cleaned_csvs/page_257.csv
# Saved Cleaned_csvs/page_258.csv
# Saved Cleaned_csvs/page_259.csv
# Saved Cleaned_csvs/page_26.csv
# Saved Cleaned_csvs/page_260.csv
# Saved Cleaned_csvs/page_261.csv
# Saved Cleaned_csvs/page_262.csv
# Saved Cleaned_csvs/page_263.csv
# Saved Cleaned_csvs/page_264.csv
# Saved Cleaned_csvs/page_265.csv
# Saved Cleaned_csvs/page_266.csv
# Saved Cleaned_csvs/page_267.csv
# Saved Cleaned_csvs/page_268.csv
# Saved Cleaned_csvs/page_269.csv
# Saved Cleaned_csvs/page_27.csv
# Saved Cleaned_csvs/page_270.csv
# Saved Cleaned_csvs/page_271.csv
# Saved Cleaned_csvs/page_272.csv
# Saved Cleaned_csvs/page_273.csv
# Saved Cleaned_csvs/page_274.csv
# Saved Cleaned_csvs/page_275.csv
# Saved Cleaned_csvs/page_276.csv
# Saved Cleaned_csvs/page_277.csv
# Saved Cleaned_csvs/page_278.csv
# Saved Cleaned_csvs/page_279.csv
# Saved Cleaned_csvs/page_28.csv
# Saved Cleaned_csvs/page_280.csv
# Saved Cleaned_csvs/page_281.csv
# Saved Cleaned_csvs/page_282.csv
# Saved Cleaned_csvs/page_283.csv
# Saved Cleaned_csvs/page_284.csv
# Saved Cleaned_csvs/page_285.csv
# Saved Cleaned_csvs/page_286.csv
# Saved Cleaned_csvs/page_287.csv
# Saved Cleaned_csvs/page_288.csv
# Saved Cleaned_csvs/page_289.csv
# Saved Cleaned_csvs/page_29.csv
# Saved Cleaned_csvs/page_290.csv
# Saved Cleaned_csvs/page_291.csv
# Saved Cleaned_csvs/page_292.csv
# Saved Cleaned_csvs/page_293.csv
# Saved Cleaned_csvs/page_294.csv
# Saved Cleaned_csvs/page_295.csv
# Saved Cleaned_csvs/page_296.csv
# Saved Cleaned_csvs/page_297.csv
# Saved Cleaned_csvs/page_298.csv
# Saved Cleaned_csvs/page_299.csv
# Saved Cleaned_csvs/page_3.csv
# Saved Cleaned_csvs/page_30.csv
# Saved Cleaned_csvs/page_300.csv
# Saved Cleaned_csvs/page_301.csv
# Saved Cleaned_csvs/page_302.csv
# Saved Cleaned_csvs/page_303.csv
# Saved Cleaned_csvs/page_304.csv
# Saved Cleaned_csvs/page_305.csv
# Saved Cleaned_csvs/page_306.csv
# Saved Cleaned_csvs/page_307.csv
# Saved Cleaned_csvs/page_308.csv
# Saved Cleaned_csvs/page_309.csv
# Saved Cleaned_csvs/page_31.csv
# Saved Cleaned_csvs/page_310.csv
# Saved Cleaned_csvs/page_311.csv
# Saved Cleaned_csvs/page_312.csv
# Saved Cleaned_csvs/page_313.csv
# Saved Cleaned_csvs/page_314.csv
# Saved Cleaned_csvs/page_315.csv
# Saved Cleaned_csvs/page_316.csv
# Saved Cleaned_csvs/page_317.csv
# Saved Cleaned_csvs/page_318.csv
# Saved Cleaned_csvs/page_319.csv
# Saved Cleaned_csvs/page_32.csv
# Saved Cleaned_csvs/page_320.csv
# Saved Cleaned_csvs/page_321.csv
# Saved Cleaned_csvs/page_322.csv
# Saved Cleaned_csvs/page_323.csv
# Saved Cleaned_csvs/page_324.csv
# Saved Cleaned_csvs/page_325.csv
# Saved Cleaned_csvs/page_326.csv
# Saved Cleaned_csvs/page_327.csv
# Saved Cleaned_csvs/page_328.csv
# Saved Cleaned_csvs/page_329.csv
# Saved Cleaned_csvs/page_33.csv
# Saved Cleaned_csvs/page_330.csv
# Saved Cleaned_csvs/page_331.csv
# Saved Cleaned_csvs/page_332.csv
# Saved Cleaned_csvs/page_333.csv
# Saved Cleaned_csvs/page_334.csv
# Saved Cleaned_csvs/page_335.csv
# Saved Cleaned_csvs/page_336.csv
# Saved Cleaned_csvs/page_337.csv
# Saved Cleaned_csvs/page_338.csv
# Saved Cleaned_csvs/page_339.csv
# Saved Cleaned_csvs/page_34.csv
# Saved Cleaned_csvs/page_340.csv
# Saved Cleaned_csvs/page_341.csv
# Saved Cleaned_csvs/page_342.csv
# Saved Cleaned_csvs/page_343.csv
# Saved Cleaned_csvs/page_344.csv
# Saved Cleaned_csvs/page_345.csv
# Saved Cleaned_csvs/page_346.csv
# Saved Cleaned_csvs/page_347.csv
# Saved Cleaned_csvs/page_348.csv
# Saved Cleaned_csvs/page_349.csv
# Saved Cleaned_csvs/page_35.csv
# Saved Cleaned_csvs/page_350.csv
# Saved Cleaned_csvs/page_351.csv
# Saved Cleaned_csvs/page_352.csv
# Saved Cleaned_csvs/page_353.csv
# Saved Cleaned_csvs/page_354.csv
# Saved Cleaned_csvs/page_355.csv
# Saved Cleaned_csvs/page_356.csv
# Saved Cleaned_csvs/page_357.csv
# Saved Cleaned_csvs/page_358.csv
# Saved Cleaned_csvs/page_359.csv
# Saved Cleaned_csvs/page_36.csv
# Saved Cleaned_csvs/page_360.csv
# Saved Cleaned_csvs/page_361.csv
# Saved Cleaned_csvs/page_362.csv
# Saved Cleaned_csvs/page_363.csv
# Saved Cleaned_csvs/page_364.csv
# Saved Cleaned_csvs/page_365.csv
# Saved Cleaned_csvs/page_366.csv
# Saved Cleaned_csvs/page_367.csv
# Saved Cleaned_csvs/page_368.csv
# Saved Cleaned_csvs/page_369.csv
# Saved Cleaned_csvs/page_37.csv
# Saved Cleaned_csvs/page_370.csv
# Saved Cleaned_csvs/page_371.csv
# Saved Cleaned_csvs/page_372.csv
# Saved Cleaned_csvs/page_373.csv
# Saved Cleaned_csvs/page_374.csv
# Saved Cleaned_csvs/page_375.csv
# Saved Cleaned_csvs/page_376.csv
# Saved Cleaned_csvs/page_377.csv
# Saved Cleaned_csvs/page_378.csv
# Saved Cleaned_csvs/page_379.csv
# Saved Cleaned_csvs/page_38.csv
# Saved Cleaned_csvs/page_380.csv
# Saved Cleaned_csvs/page_381.csv
# Saved Cleaned_csvs/page_382.csv
# Saved Cleaned_csvs/page_383.csv
# Saved Cleaned_csvs/page_384.csv
# Saved Cleaned_csvs/page_385.csv
# Saved Cleaned_csvs/page_386.csv
# Saved Cleaned_csvs/page_387.csv
# Saved Cleaned_csvs/page_388.csv
# Saved Cleaned_csvs/page_389.csv
# Saved Cleaned_csvs/page_39.csv
# Saved Cleaned_csvs/page_390.csv
# Saved Cleaned_csvs/page_391.csv
# Saved Cleaned_csvs/page_392.csv
# Saved Cleaned_csvs/page_393.csv
# Saved Cleaned_csvs/page_394.csv
# Saved Cleaned_csvs/page_395.csv
# Saved Cleaned_csvs/page_396.csv
# Saved Cleaned_csvs/page_397.csv
# Saved Cleaned_csvs/page_398.csv
# Saved Cleaned_csvs/page_399.csv
# Saved Cleaned_csvs/page_4.csv
# Saved Cleaned_csvs/page_40.csv
# Saved Cleaned_csvs/page_400.csv
# Saved Cleaned_csvs/page_401.csv
# Saved Cleaned_csvs/page_402.csv
# Saved Cleaned_csvs/page_403.csv
# Saved Cleaned_csvs/page_404.csv
# Saved Cleaned_csvs/page_405.csv
# Saved Cleaned_csvs/page_406.csv
# Saved Cleaned_csvs/page_407.csv
# Saved Cleaned_csvs/page_408.csv
# Saved Cleaned_csvs/page_409.csv
# Saved Cleaned_csvs/page_41.csv
# Saved Cleaned_csvs/page_410.csv
# Saved Cleaned_csvs/page_411.csv
# Saved Cleaned_csvs/page_412.csv
# Saved Cleaned_csvs/page_413.csv
# Saved Cleaned_csvs/page_414.csv
# Saved Cleaned_csvs/page_415.csv
# Saved Cleaned_csvs/page_416.csv
# Saved Cleaned_csvs/page_417.csv
# Saved Cleaned_csvs/page_418.csv
# Saved Cleaned_csvs/page_419.csv
# Saved Cleaned_csvs/page_42.csv
# Saved Cleaned_csvs/page_420.csv
# Saved Cleaned_csvs/page_421.csv
# Saved Cleaned_csvs/page_422.csv
# Saved Cleaned_csvs/page_423.csv
# Saved Cleaned_csvs/page_424.csv
# Saved Cleaned_csvs/page_425.csv
# Saved Cleaned_csvs/page_426.csv
# Saved Cleaned_csvs/page_427.csv
# Saved Cleaned_csvs/page_428.csv
# Saved Cleaned_csvs/page_429.csv
# Saved Cleaned_csvs/page_43.csv
# Saved Cleaned_csvs/page_430.csv
# Saved Cleaned_csvs/page_431.csv
# Saved Cleaned_csvs/page_432.csv
# Saved Cleaned_csvs/page_433.csv
# Saved Cleaned_csvs/page_434.csv
# Saved Cleaned_csvs/page_435.csv
# Saved Cleaned_csvs/page_436.csv
# Saved Cleaned_csvs/page_437.csv
# Saved Cleaned_csvs/page_438.csv
# Saved Cleaned_csvs/page_439.csv
# Saved Cleaned_csvs/page_44.csv
# Saved Cleaned_csvs/page_440.csv
# Saved Cleaned_csvs/page_441.csv
# Saved Cleaned_csvs/page_442.csv
# Saved Cleaned_csvs/page_443.csv
# Saved Cleaned_csvs/page_444.csv
# Saved Cleaned_csvs/page_445.csv
# Saved Cleaned_csvs/page_446.csv
# Saved Cleaned_csvs/page_447.csv
# Saved Cleaned_csvs/page_448.csv
# Saved Cleaned_csvs/page_449.csv
# Saved Cleaned_csvs/page_45.csv
# Saved Cleaned_csvs/page_450.csv
# Saved Cleaned_csvs/page_451.csv
# Saved Cleaned_csvs/page_452.csv
# Saved Cleaned_csvs/page_453.csv
# Saved Cleaned_csvs/page_454.csv
# Saved Cleaned_csvs/page_455.csv
# Saved Cleaned_csvs/page_456.csv
# Saved Cleaned_csvs/page_457.csv
# Saved Cleaned_csvs/page_458.csv
# Saved Cleaned_csvs/page_459.csv
# Saved Cleaned_csvs/page_46.csv
# Saved Cleaned_csvs/page_460.csv
# Saved Cleaned_csvs/page_461.csv
# Saved Cleaned_csvs/page_462.csv
# Saved Cleaned_csvs/page_463.csv
# Saved Cleaned_csvs/page_464.csv
# Saved Cleaned_csvs/page_465.csv
# Saved Cleaned_csvs/page_466.csv
# Saved Cleaned_csvs/page_467.csv
# Saved Cleaned_csvs/page_468.csv
# Saved Cleaned_csvs/page_469.csv
# Saved Cleaned_csvs/page_47.csv
# Saved Cleaned_csvs/page_470.csv
# Saved Cleaned_csvs/page_471.csv
# Saved Cleaned_csvs/page_472.csv
# Saved Cleaned_csvs/page_473.csv
# Saved Cleaned_csvs/page_474.csv
# Saved Cleaned_csvs/page_475.csv
# Saved Cleaned_csvs/page_476.csv
# Saved Cleaned_csvs/page_477.csv
# Saved Cleaned_csvs/page_478.csv
# Saved Cleaned_csvs/page_479.csv
# Saved Cleaned_csvs/page_48.csv
# Saved Cleaned_csvs/page_480.csv
# Saved Cleaned_csvs/page_481.csv
# Saved Cleaned_csvs/page_482.csv
# Saved Cleaned_csvs/page_483.csv
# Saved Cleaned_csvs/page_484.csv
# Saved Cleaned_csvs/page_485.csv
# Saved Cleaned_csvs/page_486.csv
# Saved Cleaned_csvs/page_487.csv
# Saved Cleaned_csvs/page_488.csv
# Saved Cleaned_csvs/page_489.csv
# Saved Cleaned_csvs/page_49.csv
# Saved Cleaned_csvs/page_490.csv
# Saved Cleaned_csvs/page_491.csv
# Saved Cleaned_csvs/page_492.csv
# Saved Cleaned_csvs/page_493.csv
# Saved Cleaned_csvs/page_494.csv
# Saved Cleaned_csvs/page_495.csv
# Saved Cleaned_csvs/page_496.csv
# Saved Cleaned_csvs/page_497.csv
# Saved Cleaned_csvs/page_498.csv
# Saved Cleaned_csvs/page_499.csv
# Saved Cleaned_csvs/page_5.csv
# Saved Cleaned_csvs/page_50.csv
# Saved Cleaned_csvs/page_500.csv
# Saved Cleaned_csvs/page_501.csv
# Saved Cleaned_csvs/page_502.csv
# Saved Cleaned_csvs/page_503.csv
# Saved Cleaned_csvs/page_504.csv
# Saved Cleaned_csvs/page_505.csv
# Saved Cleaned_csvs/page_506.csv
# Saved Cleaned_csvs/page_507.csv
# Saved Cleaned_csvs/page_508.csv
# Saved Cleaned_csvs/page_509.csv
# Saved Cleaned_csvs/page_51.csv
# Saved Cleaned_csvs/page_510.csv
# Saved Cleaned_csvs/page_511.csv
# Saved Cleaned_csvs/page_512.csv
# Saved Cleaned_csvs/page_513.csv
# Saved Cleaned_csvs/page_514.csv
# Saved Cleaned_csvs/page_515.csv
# Saved Cleaned_csvs/page_516.csv
# Saved Cleaned_csvs/page_517.csv
# Saved Cleaned_csvs/page_518.csv
# Saved Cleaned_csvs/page_519.csv
# Saved Cleaned_csvs/page_52.csv
# Saved Cleaned_csvs/page_520.csv
# Saved Cleaned_csvs/page_521.csv
# Saved Cleaned_csvs/page_522.csv
# Saved Cleaned_csvs/page_523.csv
# Saved Cleaned_csvs/page_524.csv
# Saved Cleaned_csvs/page_525.csv
# Saved Cleaned_csvs/page_526.csv
# Saved Cleaned_csvs/page_527.csv
# Saved Cleaned_csvs/page_528.csv
# Saved Cleaned_csvs/page_529.csv
# Saved Cleaned_csvs/page_53.csv
# Saved Cleaned_csvs/page_530.csv
# Saved Cleaned_csvs/page_531.csv
# Saved Cleaned_csvs/page_532.csv
# Saved Cleaned_csvs/page_533.csv
# Saved Cleaned_csvs/page_534.csv
# Saved Cleaned_csvs/page_535.csv
# Saved Cleaned_csvs/page_536.csv
# Saved Cleaned_csvs/page_537.csv
# Saved Cleaned_csvs/page_538.csv
# Saved Cleaned_csvs/page_539.csv
# Saved Cleaned_csvs/page_54.csv
# Saved Cleaned_csvs/page_540.csv
# Saved Cleaned_csvs/page_541.csv
# Saved Cleaned_csvs/page_542.csv
# Saved Cleaned_csvs/page_543.csv
# Saved Cleaned_csvs/page_544.csv
# Saved Cleaned_csvs/page_545.csv
# Saved Cleaned_csvs/page_546.csv
# Saved Cleaned_csvs/page_547.csv
# Saved Cleaned_csvs/page_548.csv
# Saved Cleaned_csvs/page_549.csv
# Saved Cleaned_csvs/page_55.csv
# Saved Cleaned_csvs/page_550.csv
# Saved Cleaned_csvs/page_551.csv
# Saved Cleaned_csvs/page_552.csv
# Saved Cleaned_csvs/page_553.csv
# Saved Cleaned_csvs/page_554.csv
# Saved Cleaned_csvs/page_555.csv
# Saved Cleaned_csvs/page_556.csv
# Saved Cleaned_csvs/page_557.csv
# Saved Cleaned_csvs/page_558.csv
# Saved Cleaned_csvs/page_559.csv
# Saved Cleaned_csvs/page_56.csv
# Saved Cleaned_csvs/page_560.csv
# Saved Cleaned_csvs/page_561.csv
# Saved Cleaned_csvs/page_562.csv
# Saved Cleaned_csvs/page_563.csv
# Saved Cleaned_csvs/page_564.csv
# Saved Cleaned_csvs/page_565.csv
# Saved Cleaned_csvs/page_566.csv
# Saved Cleaned_csvs/page_567.csv
# Saved Cleaned_csvs/page_568.csv
# Saved Cleaned_csvs/page_569.csv
# Saved Cleaned_csvs/page_57.csv
# Saved Cleaned_csvs/page_570.csv
# Saved Cleaned_csvs/page_571.csv
# Saved Cleaned_csvs/page_572.csv
# Saved Cleaned_csvs/page_573.csv
# Saved Cleaned_csvs/page_574.csv
# Saved Cleaned_csvs/page_575.csv
# Saved Cleaned_csvs/page_576.csv
# Saved Cleaned_csvs/page_577.csv
# Saved Cleaned_csvs/page_578.csv
# Saved Cleaned_csvs/page_579.csv
# Saved Cleaned_csvs/page_58.csv
# Saved Cleaned_csvs/page_580.csv
# Saved Cleaned_csvs/page_581.csv
# Saved Cleaned_csvs/page_582.csv
# Saved Cleaned_csvs/page_583.csv
# Saved Cleaned_csvs/page_584.csv
# Saved Cleaned_csvs/page_585.csv
# Saved Cleaned_csvs/page_586.csv
# Saved Cleaned_csvs/page_587.csv
# Saved Cleaned_csvs/page_588.csv
# Saved Cleaned_csvs/page_589.csv
# Saved Cleaned_csvs/page_59.csv
# Saved Cleaned_csvs/page_590.csv
# Saved Cleaned_csvs/page_591.csv
# Saved Cleaned_csvs/page_592.csv
# Saved Cleaned_csvs/page_593.csv
# Saved Cleaned_csvs/page_594.csv
# Saved Cleaned_csvs/page_595.csv
# Saved Cleaned_csvs/page_596.csv
# Saved Cleaned_csvs/page_597.csv
# Saved Cleaned_csvs/page_598.csv
# Saved Cleaned_csvs/page_599.csv
# Saved Cleaned_csvs/page_6.csv
# Saved Cleaned_csvs/page_60.csv
# Saved Cleaned_csvs/page_600.csv
# Saved Cleaned_csvs/page_601.csv
# Saved Cleaned_csvs/page_602.csv
# Saved Cleaned_csvs/page_603.csv
# Saved Cleaned_csvs/page_604.csv
# Saved Cleaned_csvs/page_605.csv
# Saved Cleaned_csvs/page_606.csv
# Saved Cleaned_csvs/page_607.csv
# Saved Cleaned_csvs/page_608.csv
# Saved Cleaned_csvs/page_609.csv
# Saved Cleaned_csvs/page_61.csv
# Saved Cleaned_csvs/page_610.csv
# Saved Cleaned_csvs/page_611.csv
# Saved Cleaned_csvs/page_612.csv
# Saved Cleaned_csvs/page_613.csv
# Saved Cleaned_csvs/page_614.csv
# Saved Cleaned_csvs/page_615.csv
# Saved Cleaned_csvs/page_616.csv
# Saved Cleaned_csvs/page_617.csv
# Saved Cleaned_csvs/page_618.csv
# Saved Cleaned_csvs/page_619.csv
# Saved Cleaned_csvs/page_62.csv
# Saved Cleaned_csvs/page_620.csv
# Saved Cleaned_csvs/page_621.csv
# Saved Cleaned_csvs/page_622.csv
# Saved Cleaned_csvs/page_623.csv
# Saved Cleaned_csvs/page_624.csv
# Saved Cleaned_csvs/page_625.csv
# Saved Cleaned_csvs/page_626.csv
# Saved Cleaned_csvs/page_627.csv
# Saved Cleaned_csvs/page_628.csv
# Saved Cleaned_csvs/page_629.csv
# Saved Cleaned_csvs/page_63.csv
# Saved Cleaned_csvs/page_630.csv
# Saved Cleaned_csvs/page_631.csv
# Saved Cleaned_csvs/page_632.csv
# Saved Cleaned_csvs/page_633.csv
# Saved Cleaned_csvs/page_634.csv
# Saved Cleaned_csvs/page_635.csv
# Saved Cleaned_csvs/page_636.csv
# Saved Cleaned_csvs/page_637.csv
# Saved Cleaned_csvs/page_638.csv
# Saved Cleaned_csvs/page_639.csv
# Saved Cleaned_csvs/page_64.csv
# Saved Cleaned_csvs/page_640.csv
# Saved Cleaned_csvs/page_641.csv
# Saved Cleaned_csvs/page_642.csv
# Saved Cleaned_csvs/page_643.csv
# Saved Cleaned_csvs/page_644.csv
# Saved Cleaned_csvs/page_645.csv
# Saved Cleaned_csvs/page_646.csv
# Saved Cleaned_csvs/page_647.csv
# Saved Cleaned_csvs/page_648.csv
# Saved Cleaned_csvs/page_649.csv
# Saved Cleaned_csvs/page_65.csv
# Saved Cleaned_csvs/page_650.csv
# Saved Cleaned_csvs/page_651.csv
# Saved Cleaned_csvs/page_652.csv
# Saved Cleaned_csvs/page_653.csv
# Saved Cleaned_csvs/page_654.csv
# Saved Cleaned_csvs/page_655.csv
# Saved Cleaned_csvs/page_656.csv
# Saved Cleaned_csvs/page_657.csv
# Saved Cleaned_csvs/page_658.csv
# Saved Cleaned_csvs/page_659.csv
# Saved Cleaned_csvs/page_66.csv
# Saved Cleaned_csvs/page_660.csv
# Saved Cleaned_csvs/page_661.csv
# Saved Cleaned_csvs/page_662.csv
# Saved Cleaned_csvs/page_663.csv
# Saved Cleaned_csvs/page_664.csv
# Saved Cleaned_csvs/page_665.csv
# Saved Cleaned_csvs/page_666.csv
# Saved Cleaned_csvs/page_667.csv
# Saved Cleaned_csvs/page_668.csv
# Saved Cleaned_csvs/page_669.csv
# Saved Cleaned_csvs/page_67.csv
# Saved Cleaned_csvs/page_670.csv
# Saved Cleaned_csvs/page_671.csv
# Saved Cleaned_csvs/page_672.csv
# Saved Cleaned_csvs/page_673.csv
# Saved Cleaned_csvs/page_674.csv
# Saved Cleaned_csvs/page_675.csv
# Saved Cleaned_csvs/page_676.csv
# Saved Cleaned_csvs/page_677.csv
# Saved Cleaned_csvs/page_678.csv
# Saved Cleaned_csvs/page_679.csv
# Saved Cleaned_csvs/page_68.csv
# Saved Cleaned_csvs/page_680.csv
# Saved Cleaned_csvs/page_681.csv
# Saved Cleaned_csvs/page_682.csv
# Saved Cleaned_csvs/page_683.csv
# Saved Cleaned_csvs/page_684.csv
# Saved Cleaned_csvs/page_685.csv
# Saved Cleaned_csvs/page_686.csv
# Saved Cleaned_csvs/page_687.csv
# Saved Cleaned_csvs/page_688.csv
# Saved Cleaned_csvs/page_689.csv
# Saved Cleaned_csvs/page_69.csv
# Saved Cleaned_csvs/page_690.csv
# Saved Cleaned_csvs/page_691.csv
# Saved Cleaned_csvs/page_692.csv
# Saved Cleaned_csvs/page_693.csv
# Saved Cleaned_csvs/page_694.csv
# Saved Cleaned_csvs/page_695.csv
# Saved Cleaned_csvs/page_696.csv
# Saved Cleaned_csvs/page_697.csv
# Saved Cleaned_csvs/page_698.csv
# Saved Cleaned_csvs/page_699.csv
# Saved Cleaned_csvs/page_7.csv
# Saved Cleaned_csvs/page_70.csv
# Saved Cleaned_csvs/page_700.csv
# Saved Cleaned_csvs/page_701.csv
# Saved Cleaned_csvs/page_702.csv
# Saved Cleaned_csvs/page_703.csv
# Saved Cleaned_csvs/page_704.csv
# Saved Cleaned_csvs/page_705.csv
# Saved Cleaned_csvs/page_706.csv
# Saved Cleaned_csvs/page_707.csv
# Saved Cleaned_csvs/page_708.csv
# Saved Cleaned_csvs/page_709.csv
# Saved Cleaned_csvs/page_71.csv
# Saved Cleaned_csvs/page_710.csv
# Saved Cleaned_csvs/page_711.csv
# Saved Cleaned_csvs/page_712.csv
# Saved Cleaned_csvs/page_713.csv
# Saved Cleaned_csvs/page_714.csv
# Saved Cleaned_csvs/page_715.csv
# Saved Cleaned_csvs/page_716.csv
# Saved Cleaned_csvs/page_717.csv
# Saved Cleaned_csvs/page_718.csv
# Saved Cleaned_csvs/page_719.csv
# Saved Cleaned_csvs/page_72.csv
# Saved Cleaned_csvs/page_720.csv
# Saved Cleaned_csvs/page_721.csv
# Saved Cleaned_csvs/page_722.csv
# Saved Cleaned_csvs/page_723.csv
# Saved Cleaned_csvs/page_724.csv
# Saved Cleaned_csvs/page_725.csv
# Saved Cleaned_csvs/page_726.csv
# Saved Cleaned_csvs/page_727.csv
# Saved Cleaned_csvs/page_728.csv
# Saved Cleaned_csvs/page_729.csv
# Saved Cleaned_csvs/page_73.csv
# Saved Cleaned_csvs/page_730.csv
# Saved Cleaned_csvs/page_731.csv
# Saved Cleaned_csvs/page_732.csv
# Saved Cleaned_csvs/page_733.csv
# Saved Cleaned_csvs/page_734.csv
# Saved Cleaned_csvs/page_735.csv
# Saved Cleaned_csvs/page_736.csv
# Saved Cleaned_csvs/page_737.csv
# Saved Cleaned_csvs/page_738.csv
# Saved Cleaned_csvs/page_739.csv
# Saved Cleaned_csvs/page_74.csv
# Saved Cleaned_csvs/page_740.csv
# Saved Cleaned_csvs/page_741.csv
# Saved Cleaned_csvs/page_742.csv
# Saved Cleaned_csvs/page_743.csv
# Saved Cleaned_csvs/page_744.csv
# Saved Cleaned_csvs/page_745.csv
# Saved Cleaned_csvs/page_746.csv
# Saved Cleaned_csvs/page_747.csv
# Saved Cleaned_csvs/page_748.csv
# Saved Cleaned_csvs/page_749.csv
# Saved Cleaned_csvs/page_75.csv
# Saved Cleaned_csvs/page_750.csv
# Saved Cleaned_csvs/page_751.csv
# Saved Cleaned_csvs/page_752.csv
# Saved Cleaned_csvs/page_753.csv
# Saved Cleaned_csvs/page_754.csv
# Saved Cleaned_csvs/page_755.csv
# Saved Cleaned_csvs/page_756.csv
# Saved Cleaned_csvs/page_757.csv
# Saved Cleaned_csvs/page_758.csv
# Saved Cleaned_csvs/page_759.csv
# Saved Cleaned_csvs/page_76.csv
# Saved Cleaned_csvs/page_760.csv
# Saved Cleaned_csvs/page_761.csv
# Saved Cleaned_csvs/page_762.csv
# Saved Cleaned_csvs/page_763.csv
# Saved Cleaned_csvs/page_764.csv
# Saved Cleaned_csvs/page_765.csv
# Saved Cleaned_csvs/page_766.csv
# Saved Cleaned_csvs/page_767.csv
# Saved Cleaned_csvs/page_768.csv
# Saved Cleaned_csvs/page_769.csv
# Saved Cleaned_csvs/page_77.csv
# Saved Cleaned_csvs/page_770.csv
# Saved Cleaned_csvs/page_771.csv
# Saved Cleaned_csvs/page_772.csv
# Saved Cleaned_csvs/page_773.csv
# Saved Cleaned_csvs/page_774.csv
# Saved Cleaned_csvs/page_775.csv
# Saved Cleaned_csvs/page_776.csv
# Saved Cleaned_csvs/page_777.csv
# Saved Cleaned_csvs/page_778.csv
# Saved Cleaned_csvs/page_779.csv
# Saved Cleaned_csvs/page_78.csv
# Saved Cleaned_csvs/page_780.csv
# Saved Cleaned_csvs/page_781.csv
# Saved Cleaned_csvs/page_782.csv
# Saved Cleaned_csvs/page_783.csv
# Saved Cleaned_csvs/page_784.csv
# Saved Cleaned_csvs/page_785.csv
# Saved Cleaned_csvs/page_786.csv
# Saved Cleaned_csvs/page_787.csv
# Saved Cleaned_csvs/page_788.csv
# Saved Cleaned_csvs/page_789.csv
# Saved Cleaned_csvs/page_79.csv
# Saved Cleaned_csvs/page_790.csv
# Saved Cleaned_csvs/page_791.csv
# Saved Cleaned_csvs/page_792.csv
# Saved Cleaned_csvs/page_793.csv
# Saved Cleaned_csvs/page_794.csv
# Saved Cleaned_csvs/page_795.csv
# Saved Cleaned_csvs/page_796.csv
# Saved Cleaned_csvs/page_797.csv
# Saved Cleaned_csvs/page_798.csv
# Saved Cleaned_csvs/page_799.csv
# Saved Cleaned_csvs/page_8.csv
# Saved Cleaned_csvs/page_80.csv
# Saved Cleaned_csvs/page_800.csv
# Saved Cleaned_csvs/page_801.csv
# Saved Cleaned_csvs/page_802.csv
# Saved Cleaned_csvs/page_803.csv
# Saved Cleaned_csvs/page_804.csv
# Saved Cleaned_csvs/page_805.csv
# Saved Cleaned_csvs/page_806.csv
# Saved Cleaned_csvs/page_807.csv
# Saved Cleaned_csvs/page_808.csv
# Saved Cleaned_csvs/page_809.csv
# Saved Cleaned_csvs/page_81.csv
# Saved Cleaned_csvs/page_810.csv
# Saved Cleaned_csvs/page_811.csv
# Saved Cleaned_csvs/page_812.csv
# Saved Cleaned_csvs/page_813.csv
# Saved Cleaned_csvs/page_814.csv
# Saved Cleaned_csvs/page_815.csv
# Saved Cleaned_csvs/page_816.csv
# Saved Cleaned_csvs/page_817.csv
# Saved Cleaned_csvs/page_818.csv
# Saved Cleaned_csvs/page_819.csv
# Saved Cleaned_csvs/page_82.csv
# Saved Cleaned_csvs/page_820.csv
# Saved Cleaned_csvs/page_821.csv
# Saved Cleaned_csvs/page_822.csv
# Saved Cleaned_csvs/page_823.csv
# Saved Cleaned_csvs/page_824.csv
# Saved Cleaned_csvs/page_825.csv
# Saved Cleaned_csvs/page_826.csv
# Saved Cleaned_csvs/page_827.csv
# Saved Cleaned_csvs/page_828.csv
# Saved Cleaned_csvs/page_829.csv
# Saved Cleaned_csvs/page_83.csv
# Saved Cleaned_csvs/page_830.csv
# Saved Cleaned_csvs/page_831.csv
# Saved Cleaned_csvs/page_832.csv
# Saved Cleaned_csvs/page_833.csv
# Saved Cleaned_csvs/page_834.csv
# Saved Cleaned_csvs/page_835.csv
# Saved Cleaned_csvs/page_836.csv
# Saved Cleaned_csvs/page_837.csv
# Saved Cleaned_csvs/page_838.csv
# Saved Cleaned_csvs/page_839.csv
# Saved Cleaned_csvs/page_84.csv
# Saved Cleaned_csvs/page_840.csv
# Saved Cleaned_csvs/page_841.csv
# Saved Cleaned_csvs/page_842.csv
# Saved Cleaned_csvs/page_843.csv
# Saved Cleaned_csvs/page_844.csv
# Saved Cleaned_csvs/page_845.csv
# Saved Cleaned_csvs/page_846.csv
# Saved Cleaned_csvs/page_847.csv
# Saved Cleaned_csvs/page_848.csv
# Saved Cleaned_csvs/page_849.csv
# Saved Cleaned_csvs/page_85.csv
# Saved Cleaned_csvs/page_850.csv
# Saved Cleaned_csvs/page_851.csv
# Saved Cleaned_csvs/page_852.csv
# Saved Cleaned_csvs/page_853.csv
# Saved Cleaned_csvs/page_854.csv
# Saved Cleaned_csvs/page_855.csv
# Saved Cleaned_csvs/page_856.csv
# Saved Cleaned_csvs/page_857.csv
# Saved Cleaned_csvs/page_858.csv
# Saved Cleaned_csvs/page_859.csv
# Saved Cleaned_csvs/page_86.csv
# Saved Cleaned_csvs/page_860.csv
# Saved Cleaned_csvs/page_861.csv
# Saved Cleaned_csvs/page_862.csv
# Saved Cleaned_csvs/page_863.csv
# Saved Cleaned_csvs/page_864.csv
# Saved Cleaned_csvs/page_865.csv
# Saved Cleaned_csvs/page_866.csv
# Saved Cleaned_csvs/page_867.csv
# Saved Cleaned_csvs/page_868.csv
# Saved Cleaned_csvs/page_869.csv
# Saved Cleaned_csvs/page_87.csv
# Saved Cleaned_csvs/page_870.csv
# Saved Cleaned_csvs/page_871.csv
# Saved Cleaned_csvs/page_872.csv
# Saved Cleaned_csvs/page_873.csv
# Saved Cleaned_csvs/page_874.csv
# Saved Cleaned_csvs/page_875.csv
# Saved Cleaned_csvs/page_876.csv
# Saved Cleaned_csvs/page_877.csv
# Saved Cleaned_csvs/page_878.csv
# Saved Cleaned_csvs/page_879.csv
# Saved Cleaned_csvs/page_88.csv
# Saved Cleaned_csvs/page_880.csv
# Saved Cleaned_csvs/page_881.csv
# Saved Cleaned_csvs/page_882.csv
# Saved Cleaned_csvs/page_883.csv
# Saved Cleaned_csvs/page_884.csv
# Saved Cleaned_csvs/page_885.csv
# Saved Cleaned_csvs/page_886.csv
# Saved Cleaned_csvs/page_887.csv
# Saved Cleaned_csvs/page_888.csv
# Saved Cleaned_csvs/page_889.csv
# Saved Cleaned_csvs/page_89.csv
# Saved Cleaned_csvs/page_890.csv
# Saved Cleaned_csvs/page_891.csv
# Saved Cleaned_csvs/page_892.csv
# Saved Cleaned_csvs/page_893.csv
# Saved Cleaned_csvs/page_894.csv
# Saved Cleaned_csvs/page_895.csv
# Saved Cleaned_csvs/page_896.csv
# Saved Cleaned_csvs/page_897.csv
# Saved Cleaned_csvs/page_898.csv
# Saved Cleaned_csvs/page_899.csv
# Saved Cleaned_csvs/page_9.csv
# Saved Cleaned_csvs/page_90.csv
# Saved Cleaned_csvs/page_900.csv
# Saved Cleaned_csvs/page_901.csv
# Saved Cleaned_csvs/page_902.csv
# Saved Cleaned_csvs/page_903.csv
# Saved Cleaned_csvs/page_904.csv
# Saved Cleaned_csvs/page_905.csv
# Saved Cleaned_csvs/page_906.csv
# Saved Cleaned_csvs/page_907.csv
# Saved Cleaned_csvs/page_908.csv
# Saved Cleaned_csvs/page_909.csv
# Saved Cleaned_csvs/page_91.csv
# Saved Cleaned_csvs/page_910.csv
# Saved Cleaned_csvs/page_911.csv
# Saved Cleaned_csvs/page_912.csv
# Saved Cleaned_csvs/page_913.csv
# Saved Cleaned_csvs/page_914.csv
# Saved Cleaned_csvs/page_915.csv
# Saved Cleaned_csvs/page_916.csv
# Saved Cleaned_csvs/page_917.csv
# Saved Cleaned_csvs/page_918.csv
# Saved Cleaned_csvs/page_919.csv
# Saved Cleaned_csvs/page_92.csv
# Saved Cleaned_csvs/page_920.csv
# Saved Cleaned_csvs/page_921.csv
# Saved Cleaned_csvs/page_922.csv
# Saved Cleaned_csvs/page_923.csv
# Saved Cleaned_csvs/page_924.csv
# Saved Cleaned_csvs/page_925.csv
# Saved Cleaned_csvs/page_926.csv
# Saved Cleaned_csvs/page_927.csv
# Saved Cleaned_csvs/page_928.csv
# Saved Cleaned_csvs/page_929.csv
# Saved Cleaned_csvs/page_93.csv
# Saved Cleaned_csvs/page_930.csv
# Saved Cleaned_csvs/page_931.csv
# Saved Cleaned_csvs/page_932.csv
# Saved Cleaned_csvs/page_933.csv
# Saved Cleaned_csvs/page_934.csv
# Saved Cleaned_csvs/page_935.csv
# Saved Cleaned_csvs/page_936.csv
# Saved Cleaned_csvs/page_937.csv
# Saved Cleaned_csvs/page_938.csv
# Saved Cleaned_csvs/page_939.csv
# Saved Cleaned_csvs/page_94.csv
# Saved Cleaned_csvs/page_940.csv
# Saved Cleaned_csvs/page_941.csv
# Saved Cleaned_csvs/page_942.csv
# Saved Cleaned_csvs/page_943.csv
# Saved Cleaned_csvs/page_944.csv
# Saved Cleaned_csvs/page_945.csv
# Saved Cleaned_csvs/page_946.csv
# Saved Cleaned_csvs/page_947.csv
# Saved Cleaned_csvs/page_948.csv
# Saved Cleaned_csvs/page_949.csv
# Saved Cleaned_csvs/page_95.csv
# Saved Cleaned_csvs/page_950.csv
# Saved Cleaned_csvs/page_951.csv
# Saved Cleaned_csvs/page_952.csv
# Saved Cleaned_csvs/page_953.csv
# Saved Cleaned_csvs/page_954.csv
# Saved Cleaned_csvs/page_955.csv
# Saved Cleaned_csvs/page_956.csv
# Saved Cleaned_csvs/page_957.csv
# Saved Cleaned_csvs/page_958.csv
# Saved Cleaned_csvs/page_959.csv
# Saved Cleaned_csvs/page_96.csv
# Saved Cleaned_csvs/page_960.csv
# Saved Cleaned_csvs/page_961.csv
# Saved Cleaned_csvs/page_962.csv
# Saved Cleaned_csvs/page_963.csv
# Saved Cleaned_csvs/page_964.csv
# Saved Cleaned_csvs/page_965.csv
# Saved Cleaned_csvs/page_966.csv
# Saved Cleaned_csvs/page_967.csv
# Saved Cleaned_csvs/page_968.csv
# Saved Cleaned_csvs/page_969.csv
# Saved Cleaned_csvs/page_97.csv
# Saved Cleaned_csvs/page_970.csv
# Saved Cleaned_csvs/page_971.csv
# Saved Cleaned_csvs/page_972.csv
# Saved Cleaned_csvs/page_973.csv
# Saved Cleaned_csvs/page_974.csv
# Saved Cleaned_csvs/page_975.csv
# Saved Cleaned_csvs/page_976.csv
# Saved Cleaned_csvs/page_977.csv
# Saved Cleaned_csvs/page_978.csv
# Saved Cleaned_csvs/page_979.csv
# Saved Cleaned_csvs/page_98.csv
# Saved Cleaned_csvs/page_980.csv
# Saved Cleaned_csvs/page_981.csv
# Saved Cleaned_csvs/page_982.csv
# Saved Cleaned_csvs/page_983.csv
# Saved Cleaned_csvs/page_984.csv
# Saved Cleaned_csvs/page_985.csv
# Saved Cleaned_csvs/page_986.csv
# Saved Cleaned_csvs/page_987.csv
# Saved Cleaned_csvs/page_988.csv
# Saved Cleaned_csvs/page_989.csv
# Saved Cleaned_csvs/page_99.csv
# Saved Cleaned_csvs/page_990.csv
# Saved Cleaned_csvs/page_991.csv
# Saved Cleaned_csvs/page_992.csv
# Saved Cleaned_csvs/page_993.csv
# Saved Cleaned_csvs/page_994.csv
# Saved Cleaned_csvs/page_995.csv
# Saved Cleaned_csvs/page_996.csv
# Saved Cleaned_csvs/page_997.csv
# Saved Cleaned_csvs/page_998.csv
# Saved Cleaned_csvs/page_999.csv
