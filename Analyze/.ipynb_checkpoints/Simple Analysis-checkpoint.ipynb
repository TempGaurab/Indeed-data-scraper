# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("List_of_Jobs_to_Apply.csv")
df
# Out:
#                                          Job Title  \
# 0                                AI Content Writer
# 1      AI Focused Biochemistry Postdoctoral Fellow
# 2                                 MRI Technologist
# 3                       AI Content Writer (Tier 1)
# 4              Google Cloud Platform Data Engineer
# ...                                            ...
# 14997                Competitive Intelligence Lead
# 14998         Senior Writer and Editor, AI at Work
# 14999                            AI Data Annotator
# 15000  Sustainability Go-to-Market Activation Lead
# 15001      Partner Technology Strategy AI Services
#
#                                      Company                      Location  \
# 0                             DataAnnotation                        Remote
# 1      Lawrence Berkeley National Laboratory    San Francisco Bay Area, CA
# 2                       Lenox Hill Radiology            Freeport, NY 11520
# 3                                 Outlier Ai                    California
# 4                           Publicis Sapient                   Houston, TX
# ...                                      ...                           ...
# 14997                        Grammarly, Inc.  Hybrid work in United States
# 14998                              Microsoft                 United States
# 14999                               Vistatec                 United States
# 15000                              Microsoft                 United States
# 15001                              Microsoft                 United States
#
#                         Salary($)      Job-Type  \
# 0               $20 - $25 an hour      Contract
# 1       $77,172 - $103,704 a year  Not Provided
# 2               $40 - $60 an hour     Part-time
# 3                    Not Provided  Not Provided
# 4      $115,000 - $150,000 a year     Full-time
# ...                           ...           ...
# 14997                Not Provided  Not Provided
# 14998  $103,800 - $219,200 a year     Full-time
# 14999                Not Provided  Not Provided
# 15000  $129,200 - $268,900 a year     Full-time
# 15001  $103,800 - $219,200 a year     Full-time
#
#                                          Job-Description  \
# 0      You will have conversations with chatbots in o...
# 1      Berkeley Lab’s Applied Mathematics and Computa...
# 2      Perform high quality MRI exams on incoming pat...
# 3      Flexible work schedule: Work whenever and wher...
# 4      This position requires in-depth knowledge and ...
# ...                                                  ...
# 14997  Has experience working at a senior level in co...
# 14998  The writer and editor will also contribute reg...
# 14999  Data Annotators carry out their work in an eng...
# 15000  Sitting in the Cross Solutions Sales Activatio...
# 15001  As a Partner Technology Strategist, you will d...
#
#                                                 Raw_Link
# 0      https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1      https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 2      https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 3      https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 4      https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# ...                                                  ...
# 14997  https://www.indeed.com/rc/clk?jk=416f3bf573d88...
# 14998  https://www.indeed.com/rc/clk?jk=a753f4b4e9424...
# 14999  https://www.indeed.com/rc/clk?jk=644269f566114...
# 15000  https://www.indeed.com/rc/clk?jk=da0e0b51bf349...
# 15001  https://www.indeed.com/rc/clk?jk=2f0cd40c3bb39...
#
# [15002 rows x 7 columns]

# %%
num_duplicates = df.duplicated().sum()
print(f"Number of duplicate rows: {num_duplicates}")
# Out:
# Number of duplicate rows: 0
